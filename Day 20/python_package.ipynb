# %%
#PYTHON PACKAGE MANAGER
#import webbrowser to help open any website in a different tab
import webbrowser # web browser module to open websites

# list of urls: python
url_lists = [
    'http://www.python.org',
    'https://www.linkedin.com/in/asabeneh/',
    'https://github.com/Asabeneh',
    'https://twitter.com/Asabeneh',
]

# opens the above list of websites in a different tab
for url in url_lists:
    webbrowser.open_new_tab(url)

#reading from url
import requests # importing the request module

url = 'https://www.w3.org/TR/PNG/iso_8859-1.txt' # text from a website

response = requests.get(url) # opening a network and fetching a data
print(response)
print(response.status_code) # status code, success:200
print(response.headers)     # headers information
print(response.text) # gives all the text from the page

#Reading from an Application Program Interface (API)
import requests
url = 'https://restcountries.eu/rest/v2/all'  # countries api
response = requests.get(url)  # opening a network and fetching a data
print(response) # response object
print(response.status_code)  # status code, success:200

#Exercise
import requests
from collections import Counter
import re

def get_most_frequent_words(url, top_n=10):
    response = requests.get(url)
    text = response.text
    words = re.findall(r'\b\w+\b', text.lower())
    most_common = Counter(words).most_common(top_n)
    return most_common

romeo_url = 'http://www.gutenberg.org/files/1112/1112.txt'
print(get_most_frequent_words(romeo_url))
