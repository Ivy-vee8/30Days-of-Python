# %%
#Day 17
#Exception Handling.

try:
    print(10 + '5')
except:
    print('Something went wrong')

try:
    name = input('Enter your name:')
    year_born = input('Year you were born:')
    age = 2019 - year_born
    print(f'You are {name}. And your age is {age}.')
except:
    print('Something went wrong')   # Hard to know the real error.

try:
    name = input('Enter your name:')
    year_born = input('Year you were born:')
    age = 2019 - year_born
    print(f'You are {name}. And your age is {age}.')   # Here we are able to know the type of error.
except TypeError:
    print('Type error occured')
except ValueError:
    print('Value error occured')
except ZeroDivisionError:
    print('zero division error occured')

try:
    name = input('Enter your name:')
    year_born = input('Year you born:')
    age = 2019 - int(year_born)
    print(f'You are {name}. And your age is {age}.')
except TypeError:
    print('Type error occur')
except ValueError:
    print('Value error occur')
except ZeroDivisionError:
    print('zero division error occur')
else:
    print('I usually run with the try block')
finally:
    print('I alway run.')

try:
    name = input('Enter your name:')
    year_born = input('Year you born:')
    age = 2019 - int(year_born)
    print(f'You are {name}. And your age is {age}.')  # Short form of above code.
except Exception as e:
    print(e)

names = ['Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland', 'Estonia', 'Russia']

# Unpacking
*nordic_countries, es, ru = names

# Output
print("Nordic Countries:", nordic_countries)
print("Estonia:", es)
print("Russia:", ru)
# Out:
# Something went wrong
# Something went wrong
# Type error occured
# You are Velma. And your age is 15.
# I usually run with the try block
# I alway run.
# invalid literal for int() with base 10: ''
# Nordic Countries: ['Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland']
# Estonia: Estonia
# Russia: Russia
