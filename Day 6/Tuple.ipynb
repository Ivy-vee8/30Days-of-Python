# %%
tpl=("John","Samuel","Evans","Ezekiel")
sisters=("Velma","Charity","Cheryl","Abigail","Laleti")
tpl+=sisters
print(tpl)

#modifying a tuple
siblings=('John', 'Samuel', 'Evans', 'Ezekiel', 'Velma', 'Charity', 'Cheryl', 'Abigail', 'Laleti')
x=list(siblings)
x.insert(0,"James")
x.insert(1,"Veronica")
family_members=tuple(x)
print(family_members)

#Unpack siblings and parents from family_members
family_members=('James', 'Veronica', 'John', 'Samuel', 'Evans', 'Ezekiel', 'Velma', 'Charity', 'Cheryl', 'Abigail', 'Laleti')
James,Veronica,*rest=family_members
print("\nFather:",James)
print("\nMother:",Veronica)
print("\nSiblings:",rest)

#Create fruits, vegetables and animal products tuples. Join the three tuples and assign it to a variable called food_stuff_tp.
fruits=("mango","apple","orange","banna")
vegetables=("spinach","carrot","kale")
animal_products=("ham","cheese","eggs","mutton")
food_stuff_up=fruits+vegetables+animal_products
print(food_stuff_up)

#modifying the tuple
food_stuff_up=('mango', 'apple', 'orange', 'banna', 'spinach', 'carrot', 'kale', 'ham', 'cheese', 'eggs', 'mutton')
food_stuff_it=list(food_stuff_up)
print(food_stuff_it)

#slicing a tuple
#Slice out the middle item or items from the food_stuff_tp tuple
food_stuff_up=('mango', 'apple', 'orange', 'banna', 'spinach', 'carrot', 'kale', 'ham', 'cheese', 'eggs', 'mutton')
length=len(food_stuff_it)
print(length)
middle_index=length//2
middle_item=food_stuff_up[middle_index]
print(middle_item)
#Slice out the first three items and the last three items from food_staff_lt list
food_stuff_it=['mango', 'apple', 'orange', 'banna', 'spinach', 'carrot', 'kale', 'ham', 'cheese', 'eggs', 'mutton']
first_three_elements=food_stuff_it[:3]
last_three_elements=food_stuff_it[-3:]
print("First three elements:",first_three_elements)
print("Last three elements:",last_three_elements)

#Check if an item exists in tuple
nordic_countries=("Denmark","Finland","Iceland","Norway","Sweden")
print("Estonia" in nordic_countries)
print("Iceland" in nordic_countries)
# Out:
# ('John', 'Samuel', 'Evans', 'Ezekiel', 'Velma', 'Charity', 'Cheryl', 'Abigail', 'Laleti')
# ('James', 'Veronica', 'John', 'Samuel', 'Evans', 'Ezekiel', 'Velma', 'Charity', 'Cheryl', 'Abigail', 'Laleti')
#
# Father: James
#
# Mother: Veronica
#
# Siblings: ['John', 'Samuel', 'Evans', 'Ezekiel', 'Velma', 'Charity', 'Cheryl', 'Abigail', 'Laleti']
# ('mango', 'apple', 'orange', 'banna', 'spinach', 'carrot', 'kale', 'ham', 'cheese', 'eggs', 'mutton')
# ['mango', 'apple', 'orange', 'banna', 'spinach', 'carrot', 'kale', 'ham', 'cheese', 'eggs', 'mutton']
# 11
# carrot
# First three elements: ['mango', 'apple', 'orange']
# Last three elements: ['cheese', 'eggs', 'mutton']
# False
# True
