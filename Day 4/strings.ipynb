# %%
#Escape sequence in strings
print("I hope everyone is enjoying the python challenge.\nAre you?")#line break
print("Day\tTopics\tExercises")#adding tab space or 4 spaces 
print("Day 1\t5\t5")
print("Day 2\t6\t20")
print("Day 3\t5\t23")
print("Day 4\t1\t35")
print("This is a backslash symbol (\\)") #To write a backslash
print("In every programming language it starts with \'Hello World!\'")
#string formatting
#old style string formatting using the % operator
firstname="Velma"
Lastname="Okumu"
Age=25
print("My  name is %s %s and I am %d years old."%(firstname,Lastname,Age))
#New style string formatting using the .format () method
print("My name is {} {} and I am {} years old.".format(firstname,Lastname,Age))
a=5
b=7
print("{}/{}={:.2f}".format(a,b,a/b)) #limits it to 2 digits after the decimal
#Python Strings as Sequences of Characters
#unpacking characters
name="madagascar"
a,b,c,d,e,f,g,h,i,j=name
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print(i)
print(j)
#string methods
#capitalize method
name="madagascar"
print(name.capitalize())
#count() method syntax: string.count(substring,start,end)
challenge="I will win the python challenge"
print(challenge.count("ll",0,6))
#startswith(): Checks if String Starts with the Specified String
challenge="30 days of python"
print(challenge.startswith("Thirty")) #False
#endswith() method: checks if a string ends with a specified ending
challenge="thirty days of python"
print(challenge.endswith("on"))
print(challenge.endswith("tion"))
#expandtabs: Replaces tab characters with spaces
challenge="thirty\tdays\tof\tpython"
print(challenge.expandtabs())
print(challenge.expandtabs(10))
#find(): Returns the index of the first occurence of a substring, if not found returns -1
my_challenge="I will win the python challenge"
print(my_challenge.find("i"))
#rfind(): Returns the index of the last occurence of a substring, if not found returns -1
my_challenge="I will win the python challenge"
print(my_challenge.rfind("i"))
#index(): Returns the lowest index of a substring, If the substring is not found it raises a valueError.
my_challenge="I will win the python challenge"
print(my_challenge.index("python"))
#rindex(): Returns the highest index of a substring, If the substring is not found it raises a valueError.
my_challenge="I will win the python python challenge"
print(my_challenge.rindex("python"))
#isalnum(): Checks alphanumeric character
my_challenge="Iwillwinthepythonchallenge"
print(my_challenge.isalnum())
my_challenge="Iwillwinthepythonchallengein30days"
print(my_challenge.isalnum())
my_challenge="I will win the python challenge" #space is not an alphanumeric character
print(my_challenge.isalnum())
#isalpha(): Checks if all string elements are alphabet characters (a-z and A-Z)
my_challenge="Iwillwinthepythonchallenge"
print(my_challenge.isalpha())
#isdecimal(): Checks if all characters in a string are decimal (0-9)
challenge="123"
print(challenge.isdecimal())
#isdigit(): Checks if all characters in a string are numbers (0-9 and some other unicode characters for numbers)
challenge="\u00B2"
print(challenge.isdigit())
#isnumeric(): Checks if all characters in a string are numbers or number related (just like isdigit(), just accepts more symbols, like ½)
num="\u00BD"
print(num.isnumeric())
num="9.5" #decimal point is not a number
print(num.isnumeric())
#isidentifier(): Checks for a valid identifier - it checks if a string is a valid variable name
challenge="30DaysofPython" #False because it starts with a number
print(challenge.isidentifier()) 
challenge="thirty_days_of_python"
print(challenge.isidentifier())
#islower(): Checks if all alphabet characters in the string are lowercase
challenge="Thirty days of python" #False
print(challenge.islower())
#isupper(): Checks if all alphabet characters in the string are uppercase
challenge="THIRTY DAYS OF PYTHON" #True
print(challenge.isupper())
#join(): Returns a concatenated string
web_tech=["HTML", "CSS","Javascript","React"]
print(",".join(web_tech))
#strip(): Removes all given characters starting from the beginning and end of the string and not in the middle of the string
challenge = 'thirty days of pythoonnn'
print(challenge.strip('noth')) # 'irty days of py
#replace(): Replaces substring with a given string
my_challenge="I will win the python challenge"
print(my_challenge.replace("python","coding"))
#split(): Splits the string, using given string or space as a separator
challenge="thirty days of coding"
print(challenge.split()) #splits the string using space
challenge="thirty,days,of,coding"
print(challenge.split(",")) #splits the string using a given separator
#title(): Returns a title cased string
my_challenge="I will win the python challenge"
print(my_challenge.title())
#swapcase(): Converts all uppercase characters to lowercase and all lowercase characters to uppercase characters
my_challenge="I Will Win The Python Challenge"
print(my_challenge.swapcase())
#Concatenate the string 'Coding', 'For' , 'All' to a single string, 'Coding For All'
my_string="coding","For","All"
firstitem="Coding"
seconditem="For"
thirditem="All"
print(firstitem+" "+seconditem+" "+thirditem)
#Cut(slice) out the first word of Coding For All string.
string="Coding For All"
print(string.strip("Coding"))
#Check if Coding For All string contains a word Coding using the method index, find or other methods
string="Coding For All"
print(string.find("Coding"))
print("Coding" in string)
#Split the string 'Coding For All' 
string="Coding For All"
print(string.split())
# split the string at the comma
my_string="Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" 
print(my_string.split(","))
#What is the character at index 0 in the string Coding For All
string="Coding For All"
print(string[0])
#What is the last index of the string Coding For All
string="Coding For All"
last_index=len(string)-1
print(last_index)
#Create an acronym or an abbreviation for the name 'Python For Everyon
phrase="Python For Everyone"
acronym="".join(word[0] for word in phrase.split()).upper()
print(acronym)
#Create an acronym or an abbreviation for the name 'Coding For All'
my_phrase="coding for all"
abbreviation="".join(word[0] for word in my_phrase.split()).upper()
print(abbreviation)
#Use index to determine the position of the first occurrence of o in Coding For All
phrase="Coding For All"
print(phrase.index("o"))
#Use rfind to determine the position of the last occurrence of l in Coding For All People
my_string="Coding For All People"
print(my_string.rfind("l"))
#Use rindex to find the position of the last occurrence of the word because in the following sentence:
string="You cannot end a sentence with because because because is a conjunction"
print(string.rindex("because"))
#Slice out the phrase 'because because because' in the following sentence:
word="You cannot end a sentence with because because because is a conjunction"
print(word.replace("because because because",""))
#remove the left and right trailing spaces in the given string
my_string="  Coding For All  "
print(my_string.strip())
# Join the list with a hash with space string.
my_list= ["Django", "Flask", "Bottle", "Pyramid", "Falcon"]
print(" # ".join(my_list))
#using the new line escape sequence
sentences="I am enjoying this challenge.\nI just wonder what is next"
print(sentences)
##using the tab escape sequence
print("Name\tAge\tCountry\tCity")
print("Velma\t22\tKenya\tNairobi")
#using the string formatting method
radius=10
area=3.14*radius**2
print("The area of a circle with radius {} is {}".format(radius,area))
a=8
b=6
print("{}/{}={:.3f}".format(a,b,a/b))
# Out:
# I hope everyone is enjoying the python challenge.
# Are you?
# Day	Topics	Exercises
# Day 1	5	5
# Day 2	6	20
# Day 3	5	23
# Day 4	1	35
# This is a backslash symbol (\)
# In every programming language it starts with 'Hello World!'
# My  name is Velma Okumu and I am 25 years old.
# My name is Velma Okumu and I am 25 years old.
# 5/7=0.71
# m
# a
# d
# a
# g
# a
# s
# c
# a
# r
# Madagascar
# 1
# False
# True
# False
# thirty  days    of      python
# thirty    days      of        python
# 3
# 8
# 15
# 22
# True
# True
# False
# True
# True
# True
# True
# False
# False
# True
# False
# True
# HTML,CSS,Javascript,React
# irty days of py
# I will win the coding challenge
# ['thirty', 'days', 'of', 'coding']
# ['thirty', 'days', 'of', 'coding']
# I Will Win The Python Challenge
# i wILL wIN tHE pYTHON cHALLENGE
# Coding For All
#  For All
# 0
# True
# ['Coding', 'For', 'All']
# ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']
# C
# 13
# PFE
# CFA
# 1
# 19
# ...
