# %%
#FILE HANDLING
with open('myfile.txt', 'w') as file:
    file.write("This is my file. I created it with Python!\n")

file1=open('myfile.txt')
print(file1.read())

#Read th first 6 characters of the file
f=open("myfile.txt","r")
print(f.read(6))

#Read lines
f=open("myfile.txt","r")
print(f.readline())

with open("myfile.txt","a") as file:
    file.write("This sentence will be added to the file.\n")

#File with jSON Extension- Javascript Object Notation
# we use three quotes and make it multiple line to make it more readable
person_json = '''{
    "name":"Asabeneh",
    "country":"Finland",
    "city":"Helsinki",
    "skills":["JavaScrip", "React","Python"]
}'''
print(person_json)

#Changing JSON to dictionary
import json
# JSON
person_json = '''{
    "name": "Asabeneh",
    "country": "Finland",
    "city": "Helsinki",
    "skills": ["JavaScrip", "React", "Python"]
}'''
# let's change JSON to dictionary
person_dct = json.loads(person_json)
print(type(person_dct))
print(person_dct)
print(person_dct['name'])

#Changing dictionary to JSON-  we use loads method from JSON module
import json
# python dictionary
person = {
    "name": "Asabeneh",
    "country": "Finland",
    "city": "Helsinki",
    "skills": ["JavaScrip", "React", "Python"]
}
# let's convert it to  json- we use dumps method from JSON module
person_json = json.dumps(person, indent=4) # indent could be 2, 4, 8. It beautifies the json
print(type(person_json))
print(person_json)
# Out:
# This is my file. I created it with Python!
#
# This i
# This is my file. I created it with Python!
#
# {
#     "name":"Asabeneh",
#     "country":"Finland",
#     "city":"Helsinki",
#     "skills":["JavaScrip", "React","Python"]
# }
# <class 'dict'>
# {'name': 'Asabeneh', 'country': 'Finland', 'city': 'Helsinki', 'skills': ['JavaScrip', 'React', 'Python']}
# Asabeneh
# <class 'str'>
# {
#     "name": "Asabeneh",
#     "country": "Finland",
#     "city": "Helsinki",
#     "skills": [
#         "JavaScrip",
#         "React",
#         "Python"
#     ]
# }
