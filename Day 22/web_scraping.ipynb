# %%
#Web scraping - is the process of extracting and collecting data from websites and storing it on a local machine or in a database.

import requests
from bs4 import BeautifulSoup
url = 'https://archive.ics.uci.edu/ml/datasets.php'

# Lets use the requests get method to fetch the data from url

response = requests.get(url)
# lets check the status
status = response.status_code
print(status) # 200 means the fetching was successful

#Using beautifulSoup to parse content from the page
import requests
from bs4 import BeautifulSoup
url = 'https://archive.ics.uci.edu/ml/datasets.php'

response = requests.get(url)
content = response.content # we get all the content from the website
soup = BeautifulSoup(content, 'html.parser') # beautiful soup will give a chance to parse
print(soup.title) # <title>UCI Machine Learning Repository: Data Sets</title>
print(soup.title.get_text()) # UCI Machine Learning Repository: Data Sets
print(soup.body) # gives the whole page on the website
print(response.status_code)

tables = soup.find_all('table', {'cellpadding':'3'})
# We are targeting the table with cellpadding attribute with the value of 3
# We can select using id, class or HTML tag , for more information check the beautifulsoup doc
table = tables[0] # the result is a list, we are taking out data from it
for td in table.find('tr').find_all('td'):
    print(td.text)

#Exercises

#1 Boston University Facts and Stats
import requests
from bs4 import BeautifulSoup
import json

url = 'http://www.bu.edu/president/boston-university-facts-stats/'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

data = {}
for i, ul in enumerate(soup.find_all(['ul', 'ol'])):
    items = [li.get_text(strip=True) for li in ul.find_all('li')]
    if items:
        data[f"section_{i+1}"] = items

with open('bu_facts_stats.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=2)

#2 UCI Machine Learning Repository Table
import pandas as pd

url = 'https://archive.ics.uci.edu/ml/datasets.php'
tables = pd.read_html(url)
uci_datasets = tables[0]  # First table contains the datasets

uci_datasets.to_json('uci_datasets.json', orient='records', indent=2)

#3 List of Presidents of the United States (Wikipedia)
url = 'https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States'
tables = pd.read_html(url)
presidents_table = tables[1]  # The correct table might change position

presidents_table.to_json('us_presidents.json', orient='records', indent=2)
